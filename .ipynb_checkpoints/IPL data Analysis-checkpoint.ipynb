# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading CSV and Performing basic analyis on Data

# %%
df =  pd.read_csv(r'C:/Users/OMKAR/Documents/PortFolio/Indian-Premier-League-IPL-Data-Analysis/deliveries.csv')
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
df.shape
# Out:
# (150460, 21)

# %%
df.dtypes
# Out:
# match_id             int64
# inning               int64
# batting_team        object
# bowling_team        object
# over                 int64
# ball                 int64
# batsman             object
# non_striker         object
# bowler              object
# is_super_over        int64
# wide_runs            int64
# bye_runs             int64
# legbye_runs          int64
# noball_runs          int64
# penalty_runs         int64
# batsman_runs         int64
# extra_runs           int64
# total_runs           int64
# player_dismissed    object
# dismissal_kind      object
# fielder             object
# dtype: object

# %% [markdown]
# ### Indepth analysis of David Warner performance

# %%
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %% [markdown]
# #### filtering out enteries corresponds to Davud Warner

# %%
filt = df['batsman']== 'DA Warner'
df_warner = df[filt]
df_warner
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 150283       636       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 150284       636       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 150288       636       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 150291       636       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 150292       636       1  Sunrisers Hyderabad  Royal Challengers Bangalore
#
# ...

# %% [markdown]
# #### Reason for dismiss

# %%
dis = df_warner['dismissal_kind'].value_counts()
dis
# Out:
# caught               62
# bowled               21
# run out               8
# lbw                   4
# stumped               4
# caught and bowled     2
# hit wicket            1
# Name: dismissal_kind, dtype: int64

# %%
dis.plot.pie(figsize = (20,12), autopct='%.1f%%')
# Out:
# <AxesSubplot:ylabel='dismissal_kind'>

# %% [markdown]
# #### Total 4 runs hitted

# %%
len(df_warner[df_warner['batsman_runs']==4])
# Out:
# 401

# %% [markdown]
# #### Total 6 runs hitted

# %%
len(df_warner[df_warner['batsman_runs']==6])
# Out:
# 160

# %% [markdown]
# #### Total run Distributionn of David Warner

# %%
run = df_warner['batsman_runs'].value_counts()
run
# Out:
# 0    1124
# 1     997
# 4     401
# 2     207
# 6     160
# 3      13
# Name: batsman_runs, dtype: int64

# %%
run.plot.pie(figsize = (20,12), autopct='%.1f%%')
# Out:
# <AxesSubplot:ylabel='batsman_runs'>

# %% [markdown]
# ### Score Distribution for teams by Innings

# %%
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %% [markdown]
# #### Changing  values of batting and bowling team columns

# %%
df['batting_team'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Royal Challengers Bangalore',
#        'Mumbai Indians', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants'],
#       dtype=object)

# %%
teams = {'Sunrisers Hyderabad' :  'SRH', 'Royal Challengers Bangalore' : 'RCB',
       'Mumbai Indians' : 'MI', 'Rising Pune Supergiant' : 'RPS', 'Gujarat Lions' : 'GL',
       'Kolkata Knight Riders' : 'KKR', 'Kings XI Punjab' : 'KXIP', 'Delhi Daredevils' : 'DD',
       'Chennai Super Kings' : 'CSK', 'Rajasthan Royals' : 'RR', 'Deccan Chargers' : 'DC',
       'Kochi Tuskers Kerala' : 'KTK', 'Pune Warriors' : 'PW', 'Rising Pune Supergiants' : 'RPS'}

# %%
df['batting_team'] = df['batting_team'].map(teams)
df['bowling_team'] = df['bowling_team'].map(teams)

# %%
df.head()
# Out:
#    match_id  inning batting_team bowling_team  over  ball    batsman  \
# 0         1       1          SRH          RCB     1     1  DA Warner
# 1         1       1          SRH          RCB     1     2  DA Warner
# 2         1       1          SRH          RCB     1     3  DA Warner
# 3         1       1          SRH          RCB     1     4  DA Warner
# 4         1       1          SRH          RCB     1     5  DA Warner
#
#   non_striker    bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 0    S Dhawan  TS Mills              0  ...         0            0
# 1    S Dhawan  TS Mills              0  ...         0            0
# 2    S Dhawan  TS Mills              0  ...         0            0
# 3    S Dhawan  TS Mills              0  ...         0            0
# 4    S Dhawan  TS Mills              0  ...         0            0
#
#    noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  \
# 0            0             0             0           0           0
# ...

# %% [markdown]
# #### Dastaframe of score distribution for teams by innings

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
runs_df  = df.groupby(['match_id','inning','batting_team'])['total_runs'].sum().reset_index()
runs_df
# Out:
#       match_id  inning batting_team  total_runs
# 0            1       1          SRH         207
# 1            1       2          RCB         172
# 2            2       1           MI         184
# 3            2       2          RPS         187
# 4            3       1           GL         183
# ...        ...     ...          ...         ...
# 1279       634       2          KKR         140
# 1280       635       1           GL         162
# 1281       635       2          SRH         163
# 1282       636       1          SRH         208
# 1283       636       2          RCB         200
#
# [1284 rows x 4 columns]

# %%
innings1 = runs_df[runs_df['inning']==1]
innings2 = runs_df[runs_df['inning']==2]

# %% [markdown]
# #### Visualization

# %%
sns.boxplot(x = 'batting_team', y = 'total_runs', data = innings1)
# Out:
# <AxesSubplot:xlabel='batting_team', ylabel='total_runs'>

# %%
sns.boxplot(x = 'batting_team', y = 'total_runs', data = innings2)
# Out:
# <AxesSubplot:xlabel='batting_team', ylabel='total_runs'>

# %% [markdown]
# ### How many teams score more than 200

# %%
high_score  = df.groupby(['match_id','inning','batting_team', 'bowling_team'])['total_runs'].sum().reset_index()
high_score
# Out:
#       match_id  inning batting_team bowling_team  total_runs
# 0            1       1          SRH          RCB         207
# 1            1       2          RCB          SRH         172
# 2            2       1           MI          RPS         184
# 3            2       2          RPS           MI         187
# 4            3       1           GL          KKR         183
# ...        ...     ...          ...          ...         ...
# 1279       634       2          KKR          SRH         140
# 1280       635       1           GL          SRH         162
# 1281       635       2          SRH           GL         163
# 1282       636       1          SRH          RCB         208
# 1283       636       2          RCB          SRH         200
#
# [1284 rows x 5 columns]

# %%
score_200 = high_score[high_score['total_runs'] >= 200]
score_200
# Out:
#       match_id  inning batting_team bowling_team  total_runs
# 0            1       1          SRH          RCB         207
# 16           9       1           DD          RPS         205
# 38          20       1          RCB           GL         213
# 62          32       1          SRH         KXIP         207
# 72          36       1          SRH          KKR         209
# ...        ...     ...          ...          ...         ...
# 1250       620       1          RCB           GL         248
# 1256       623       1           MI           DD         206
# 1262       626       1          RCB         KXIP         211
# 1282       636       1          SRH          RCB         208
# 1283       636       2          RCB          SRH         200
#
# [67 rows x 5 columns]

# %% [markdown]
# #### Visualization

# %%
sns.countplot(score_200['batting_team'])
# Out:
# C:\Users\OMKAR\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='batting_team', ylabel='count'>

# %%
sns.countplot(score_200['bowling_team'])
# Out:
# C:\Users\OMKAR\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bowling_team', ylabel='count'>

# %% [markdown]
# ### Batsman Comparission

# %%
df.head()
# Out:
#    match_id  inning batting_team bowling_team  over  ball    batsman  \
# 0         1       1          SRH          RCB     1     1  DA Warner
# 1         1       1          SRH          RCB     1     2  DA Warner
# 2         1       1          SRH          RCB     1     3  DA Warner
# 3         1       1          SRH          RCB     1     4  DA Warner
# 4         1       1          SRH          RCB     1     5  DA Warner
#
#   non_striker    bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 0    S Dhawan  TS Mills              0  ...         0            0
# 1    S Dhawan  TS Mills              0  ...         0            0
# 2    S Dhawan  TS Mills              0  ...         0            0
# 3    S Dhawan  TS Mills              0  ...         0            0
# 4    S Dhawan  TS Mills              0  ...         0            0
#
#    noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  \
# 0            0             0             0           0           0
# ...

# %% [markdown]
# #### Top Batsmen with balls played

# %%
balls_df = df.groupby('batsman')['ball'].count().reset_index()
balls_df
# Out:
#             batsman  ball
# 0    A Ashish Reddy   196
# 1        A Chandila     7
# 2          A Chopra    75
# 3       A Choudhary    20
# 4        A Flintoff    57
# ..              ...   ...
# 456     YV Takawale   183
# 457   Yashpal Singh    67
# 458     Younis Khan     7
# 459    Yuvraj Singh  2050
# 460          Z Khan   141
#
# [461 rows x 2 columns]

# %% [markdown]
# ####  Top Batsmen with score

# %%
run_df = df.groupby('batsman')['batsman_runs'].sum().reset_index()
run_df
# Out:
#             batsman  batsman_runs
# 0    A Ashish Reddy           280
# 1        A Chandila             4
# 2          A Chopra            53
# 3       A Choudhary            25
# 4        A Flintoff            62
# ..              ...           ...
# 456     YV Takawale           192
# 457   Yashpal Singh            47
# 458     Younis Khan             3
# 459    Yuvraj Singh          2591
# 460          Z Khan           117
#
# [461 rows x 2 columns]

# %% [markdown]
# #### Dataframe with 4 runs

# %%
four_df  = df[df['batsman_runs'] == 4]
four_df
# Out:
#         match_id  inning batting_team bowling_team  over  ball        batsman  \
# 2              1       1          SRH          RCB     1     3      DA Warner
# 8              1       1          SRH          RCB     2     2      DA Warner
# 13             1       1          SRH          RCB     2     7   MC Henriques
# 30             1       1          SRH          RCB     5     5   MC Henriques
# 32             1       1          SRH          RCB     6     1       S Dhawan
# ...          ...     ...          ...          ...   ...   ...            ...
# 150403       636       2          RCB          SRH    11     4        V Kohli
# 150407       636       2          RCB          SRH    12     2        V Kohli
# 150418       636       2          RCB          SRH    14     1       KL Rahul
# 150447       636       2          RCB          SRH    18     6    Sachin Baby
# 150459       636       2          RCB          SRH    20     6  Iqbal Abdulla
#
# ...

# %% [markdown]
# #### Batsmen with highest  4 runs

# %%
runs_4 = four_df.groupby('batsman')['batsman_runs'].count().reset_index()
runs_4.columns = ['batsman', '4s']
runs_4
# Out:
#             batsman   4s
# 0    A Ashish Reddy   16
# 1          A Chopra    7
# 2       A Choudhary    1
# 3        A Flintoff    5
# 4          A Kumble    3
# ..              ...  ...
# 363       YK Pathan  240
# 364     YV Takawale   26
# 365   Yashpal Singh    5
# 366    Yuvraj Singh  205
# 367          Z Khan   11
#
# [368 rows x 2 columns]

# %% [markdown]
# #### Batsmen with highest 6 runs

# %%
six_df  = df[df['batsman_runs'] == 6]
six_df
# Out:
#         match_id  inning batting_team bowling_team  over  ball       batsman  \
# 10             1       1          SRH          RCB     2     4     DA Warner
# 47             1       1          SRH          RCB     8     4  MC Henriques
# 75             1       1          SRH          RCB    13     2  Yuvraj Singh
# 89             1       1          SRH          RCB    15     3  Yuvraj Singh
# 91             1       1          SRH          RCB    15     5  MC Henriques
# ...          ...     ...          ...          ...   ...   ...           ...
# 150395       636       2          RCB          SRH    10     2       V Kohli
# 150413       636       2          RCB          SRH    13     2       V Kohli
# 150428       636       2          RCB          SRH    15     5     SR Watson
# 150440       636       2          RCB          SRH    17     5     STR Binny
# 150453       636       2          RCB          SRH    19     6   Sachin Baby
#
# ...

# %%
runs_6 = six_df.groupby('batsman')['batsman_runs'].count().reset_index()
runs_6.columns = ['batsman', '6s']
runs_6
# Out:
#              batsman   6s
# 0     A Ashish Reddy   15
# 1        A Choudhary    1
# 2         A Flintoff    2
# 3           A Mishra    5
# 4           A Mithun    1
# ..               ...  ...
# 296  Y Venugopal Rao   37
# 297        YK Pathan  149
# 298      YV Takawale    3
# 299     Yuvraj Singh  141
# 300           Z Khan    2
#
# [301 rows x 2 columns]

# %% [markdown]
# #### Concatinating all 4 dataframes

# %%
players_df = pd.concat([run_df, balls_df.iloc[:,1], runs_4.iloc[:,1], runs_6.iloc[:,1]],axis= 1)
players_df
# Out:
#             batsman  batsman_runs  ball    4s    6s
# 0    A Ashish Reddy           280   196  16.0  15.0
# 1        A Chandila             4     7   7.0   1.0
# 2          A Chopra            53    75   1.0   2.0
# 3       A Choudhary            25    20   5.0   5.0
# 4        A Flintoff            62    57   3.0   1.0
# ..              ...           ...   ...   ...   ...
# 456     YV Takawale           192   183   NaN   NaN
# 457   Yashpal Singh            47    67   NaN   NaN
# 458     Younis Khan             3     7   NaN   NaN
# 459    Yuvraj Singh          2591  2050   NaN   NaN
# 460          Z Khan           117   141   NaN   NaN
#
# [461 rows x 5 columns]

# %%
players_df.fillna(0, inplace = True)

# %%
players_df
# Out:
#             batsman  batsman_runs  ball    4s    6s
# 0    A Ashish Reddy           280   196  16.0  15.0
# 1        A Chandila             4     7   7.0   1.0
# 2          A Chopra            53    75   1.0   2.0
# 3       A Choudhary            25    20   5.0   5.0
# 4        A Flintoff            62    57   3.0   1.0
# ..              ...           ...   ...   ...   ...
# 456     YV Takawale           192   183   0.0   0.0
# 457   Yashpal Singh            47    67   0.0   0.0
# 458     Younis Khan             3     7   0.0   0.0
# 459    Yuvraj Singh          2591  2050   0.0   0.0
# 460          Z Khan           117   141   0.0   0.0
#
# [461 rows x 5 columns]

# %% [markdown]
# #### Calculating Strike rate

# %%
players_df['strike_rate'] = players_df['batsman_runs']/players_df['ball']
players_df
# Out:
#             batsman  batsman_runs  ball    4s    6s  strike_rate
# 0    A Ashish Reddy           280   196  16.0  15.0     1.428571
# 1        A Chandila             4     7   7.0   1.0     0.571429
# 2          A Chopra            53    75   1.0   2.0     0.706667
# 3       A Choudhary            25    20   5.0   5.0     1.250000
# 4        A Flintoff            62    57   3.0   1.0     1.087719
# ..              ...           ...   ...   ...   ...          ...
# 456     YV Takawale           192   183   0.0   0.0     1.049180
# 457   Yashpal Singh            47    67   0.0   0.0     0.701493
# 458     Younis Khan             3     7   0.0   0.0     0.428571
# 459    Yuvraj Singh          2591  2050   0.0   0.0     1.263902
# 460          Z Khan           117   141   0.0   0.0     0.829787
#
# [461 rows x 6 columns]

# %% [markdown]
# #### Maximum score of batsman in individual match

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
max_df = df.groupby(['match_id','batsman','batting_team'])['batsman_runs'].sum().reset_index()
max_df
# Out:
#       match_id       batsman batting_team  batsman_runs
# 0            1   A Choudhary          RCB             6
# 1            1   BCJ Cutting          SRH            16
# 2            1      CH Gayle          RCB            32
# 3            1     DA Warner          SRH            14
# 4            1      DJ Hooda          SRH            16
# ...        ...           ...          ...           ...
# 9510       636     SR Watson          RCB            11
# 9511       636     STR Binny          RCB             9
# 9512       636   Sachin Baby          RCB            18
# 9513       636       V Kohli          RCB            54
# 9514       636  Yuvraj Singh          SRH            38
#
# [9515 rows x 4 columns]

# %%
max_runs = max_df.groupby('batsman')['batsman_runs'].max().reset_index()
max_runs.columns = ['batsman', 'max_run']
max_runs
# Out:
#             batsman  max_run
# 0    A Ashish Reddy       36
# 1        A Chandila        4
# 2          A Chopra       24
# 3       A Choudhary       15
# 4        A Flintoff       24
# ..              ...      ...
# 456     YV Takawale       45
# 457   Yashpal Singh       20
# 458     Younis Khan        3
# 459    Yuvraj Singh       83
# 460          Z Khan       23
#
# [461 rows x 2 columns]

# %%
players1_df = pd.concat([players_df, max_runs.iloc[:,1]], axis = 1)
players1_df
# Out:
#             batsman  batsman_runs  ball    4s    6s  strike_rate  max_run
# 0    A Ashish Reddy           280   196  16.0  15.0     1.428571       36
# 1        A Chandila             4     7   7.0   1.0     0.571429        4
# 2          A Chopra            53    75   1.0   2.0     0.706667       24
# 3       A Choudhary            25    20   5.0   5.0     1.250000       15
# 4        A Flintoff            62    57   3.0   1.0     1.087719       24
# ..              ...           ...   ...   ...   ...          ...      ...
# 456     YV Takawale           192   183   0.0   0.0     1.049180       45
# 457   Yashpal Singh            47    67   0.0   0.0     0.701493       20
# 458     Younis Khan             3     7   0.0   0.0     0.428571        3
# 459    Yuvraj Singh          2591  2050   0.0   0.0     1.263902       83
# 460          Z Khan           117   141   0.0   0.0     0.829787       23
#
# [461 rows x 7 columns]

# %% [markdown]
# ### Top 10 Batsman

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
df_top =  df.groupby('batsman')['batsman_runs'].sum()
df_top
# Out:
# batsman
# A Ashish Reddy     280
# A Chandila           4
# A Chopra            53
# A Choudhary         25
# A Flintoff          62
#                   ...
# YV Takawale        192
# Yashpal Singh       47
# Younis Khan          3
# Yuvraj Singh      2591
# Z Khan             117
# Name: batsman_runs, Length: 461, dtype: int64

# %%
top = df_top.sort_values(ascending = False)[:10]
top
# Out:
# batsman
# SK Raina          4548
# V Kohli           4423
# RG Sharma         4207
# G Gambhir         4132
# DA Warner         4014
# RV Uthappa        3778
# CH Gayle          3651
# S Dhawan          3561
# MS Dhoni          3560
# AB de Villiers    3486
# Name: batsman_runs, dtype: int64

# %% [markdown]
# #### Visualization

# %%
top.plot.bar(figsize = (20,12), color = 'Red')
# Out:
# <AxesSubplot:xlabel='batsman'>
